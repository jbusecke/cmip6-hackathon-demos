# %%
# cmip catalogue search

# %%
import os
os.environ['NUMPY_EXPERIMENTAL_ARRAY_FUNCTION'] = '0'

from matplotlib import pyplot as plt
import numpy as np
import xarray as xr
import gcsfs
from xhistogram.xarray import histogram

# %matplotlib inline
plt.rcParams['figure.figsize'] = 12, 6
# %config InlineBackend.figure_format = 'retina'

# %%
import pandas as pd
df = pd.read_csv('https://storage.googleapis.com/pangeo-cmip6/pangeo-cmip6-zarr-consolidated-stores.csv')
df.head()
# Out:
#   activity_id institution_id source_id experiment_id member_id table_id  \
# 0  AerChemMIP            BCC  BCC-ESM1        ssp370  r1i1p1f1     Amon
# 1  AerChemMIP            BCC  BCC-ESM1        ssp370  r1i1p1f1     Amon
# 2  AerChemMIP            BCC  BCC-ESM1        ssp370  r1i1p1f1     Amon
# 3  AerChemMIP            BCC  BCC-ESM1        ssp370  r1i1p1f1     Amon
# 4  AerChemMIP            BCC  BCC-ESM1        ssp370  r1i1p1f1     Amon
#
#   variable_id grid_label                                             zstore  \
# 0          pr         gn  gs://cmip6/AerChemMIP/BCC/BCC-ESM1/ssp370/r1i1...
# 1        prsn         gn  gs://cmip6/AerChemMIP/BCC/BCC-ESM1/ssp370/r1i1...
# 2         tas         gn  gs://cmip6/AerChemMIP/BCC/BCC-ESM1/ssp370/r1i1...
# 3      tasmax         gn  gs://cmip6/AerChemMIP/BCC/BCC-ESM1/ssp370/r1i1...
# 4      tasmin         gn  gs://cmip6/AerChemMIP/BCC/BCC-ESM1/ssp370/r1i1...
#
#    dcpp_init_year
# 0             NaN
# 1             NaN
# ...

# %%
institutes = np.unique(df.institution_id)

# %%
pick = df[ (df.variable_id == 'thetao') & (df.experiment_id == 'piControl') &
        (df.grid_label == 'gn') #&
     ]
pick
# Out:
#       activity_id       institution_id        source_id experiment_id  \
# 211          CMIP                  AWI    AWI-CM-1-1-MR     piControl
# 481          CMIP                  BCC      BCC-CSM2-MR     piControl
# 734          CMIP                  BCC         BCC-ESM1     piControl
# 860          CMIP                 CAMS      CAMS-CSM1-0     piControl
# 4082         CMIP                CCCma          CanESM5     piControl
# 4888         CMIP         CNRM-CERFACS       CNRM-CM6-1     piControl
# 5391         CMIP         CNRM-CERFACS      CNRM-ESM2-1     piControl
# 5641         CMIP  EC-Earth-Consortium     EC-Earth3-LR     piControl
# 5772         CMIP  EC-Earth-Consortium    EC-Earth3-Veg     piControl
# 5911         CMIP  EC-Earth-Consortium        EC-Earth3     piControl
# 8927         CMIP                MIROC       MIROC-ES2L     piControl
# 9480         CMIP                MIROC           MIROC6     piControl
# ...

# %%
# pick = df[(df.institution_id == 'NOAA-GFDL') & (df.variable_id == 'uo') &
#            (df.experiment_id == 'historical') &(df.grid_label == 'gn') #&
#          ]
# pick

# pick = df[(df.institution_id == 'NCAR') & (df.variable_id == 'thetao') &
#            (df.experiment_id == 'historical') &(df.grid_label == 'gn') #&
#          ]
# pick

# pick = df[(df.institution_id == 'IPSL') & (df.variable_id == 'thetao') &
#            (df.experiment_id == 'historical') &(df.grid_label == 'gn') #&
#          ]
# pick

# pick = df[(df.institution_id == 'NASA-GISS') & (df.variable_id == 'thetao') &
#            (df.experiment_id == 'historical') &(df.grid_label == 'gn') #&
#          ]
# pick

pick = df[(df.institution_id == 'NOAA-GFDL') & (df.variable_id == 'thkcello') #&
#            (df.experiment_id == 'historical') &(df.grid_label == 'gn') #&
         ]
pick

# # NASA-GISS
# Out:
# Empty DataFrame
# Columns: [activity_id, institution_id, source_id, experiment_id, member_id, table_id, variable_id, grid_label, zstore, dcpp_init_year]
# Index: []

# %%
{k:{}}(pick['source_id'].values, pick['zstore'].values)
# Out:
# (array(['AWI-CM-1-1-MR', 'BCC-CSM2-MR', 'BCC-ESM1', 'CAMS-CSM1-0',
#         'CanESM5', 'CNRM-CM6-1', 'CNRM-ESM2-1', 'EC-Earth3-LR',
#         'EC-Earth3-Veg', 'EC-Earth3', 'MIROC-ES2L', 'MIROC6',
#         'HadGEM3-GC31-LL', 'UKESM1-0-LL', 'GISS-E2-1-G-CC', 'GISS-E2-1-G',
#         'CESM2-WACCM', 'CESM2', 'GFDL-CM4', 'GFDL-ESM4', 'NESM3',
#         'SAM0-UNICON', 'MCM-UA-1-0'], dtype=object),
#  array(['gs://cmip6/CMIP/AWI/AWI-CM-1-1-MR/piControl/r1i1p1f1/Omon/thetao/gn/',
#         'gs://cmip6/CMIP/BCC/BCC-CSM2-MR/piControl/r1i1p1f1/Omon/thetao/gn/',
#         'gs://cmip6/CMIP/BCC/BCC-ESM1/piControl/r1i1p1f1/Omon/thetao/gn/',
#         'gs://cmip6/CMIP/CAMS/CAMS-CSM1-0/piControl/r1i1p1f1/Omon/thetao/gn/',
#         'gs://cmip6/CMIP/CCCma/CanESM5/piControl/r1i1p1f1/Omon/thetao/gn/',
#         'gs://cmip6/CMIP/CNRM-CERFACS/CNRM-CM6-1/piControl/r1i1p1f2/Omon/thetao/gn/',
#         'gs://cmip6/CMIP/CNRM-CERFACS/CNRM-ESM2-1/piControl/r1i1p1f2/Omon/thetao/gn/',
# ...

# %%
import qgrid
df = pd.read_csv('http://fletcher.ldeo.columbia.edu/catalogs/Variables.csv')
qgrid.show_grid(df, column_definitions={'description':{'width':400}})
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
df

# %%
def read_data(uri):
    gcs = gcsfs.GCSFileSystem(token='anon')
    ds = xr.open_zarr(gcs.get_mapper(uri), consolidated=True)
    return ds

# %%
no3 = read_data('gs://cmip6/CMIP/IPSL/IPSL-CM6A-LR/historical/r10i1p1f1/Omon/no3/gn/')
no3
# Out:
# <xarray.Dataset>
# Dimensions:         (axis_nbounds: 2, nvertex: 4, olevel: 75, time: 1980, x: 362, y: 332)
# Coordinates:
#     bounds_nav_lat  (y, x, nvertex) float32 dask.array<chunksize=(332, 362, 4), meta=np.ndarray>
#     bounds_nav_lon  (y, x, nvertex) float32 dask.array<chunksize=(332, 362, 4), meta=np.ndarray>
#     nav_lat         (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     nav_lon         (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#   * olevel          (olevel) float32 0.50576 1.5558553 ... 5698.0605 5902.0576
#     olevel_bounds   (olevel, axis_nbounds) float32 dask.array<chunksize=(75, 2), meta=np.ndarray>
#   * time            (time) datetime64[ns] 1850-01-16T12:00:00 ... 2014-12-16T12:00:00
#     time_bounds     (time, axis_nbounds) datetime64[ns] dask.array<chunksize=(1980, 2), meta=np.ndarray>
# Dimensions without coordinates: axis_nbounds, nvertex, x, y
# Data variables:
# ...

# %%
u = read_data('gs://cmip6/CMIP/IPSL/IPSL-CM6A-LR/historical/r10i1p1f1/Omon/uo/gn/')

# %%
u
# Out:
# <xarray.Dataset>
# Dimensions:         (axis_nbounds: 2, nvertex: 4, olevel: 75, time: 1980, x: 362, y: 332)
# Coordinates:
#     bounds_nav_lat  (y, x, nvertex) float32 dask.array<chunksize=(332, 362, 4), meta=np.ndarray>
#     bounds_nav_lon  (y, x, nvertex) float32 dask.array<chunksize=(332, 362, 4), meta=np.ndarray>
#     nav_lat         (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     nav_lon         (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#   * olevel          (olevel) float32 0.50576 1.5558553 ... 5698.0605 5902.0576
#     olevel_bounds   (olevel, axis_nbounds) float32 dask.array<chunksize=(75, 2), meta=np.ndarray>
#   * time            (time) datetime64[ns] 1850-01-16T12:00:00 ... 2014-12-16T12:00:00
#     time_bounds     (time, axis_nbounds) datetime64[ns] dask.array<chunksize=(1980, 2), meta=np.ndarray>
# Dimensions without coordinates: axis_nbounds, nvertex, x, y
# Data variables:
# ...
